# %% [markdown]
# 1. What are data structures, and why are they important?
# Answer: Data structures are ways to organize and store data efficiently for operations like searching, sorting, and modifying data. They help optimize performance in programming.
#
# 2. Explain the difference between mutable and immutable data types with examples.
# Answer:
#
# Mutable data types can be changed after creation (e.g., list, dictionary, set).
# Immutable data types cannot be changed after creation (e.g., string, tuple, int, float).
# 3. What are the main differences between lists and tuples in Python?
# Answer:
#
# Lists are mutable and can be modified. Example: [1, 2, 3]
# Tuples are immutable and cannot be changed. Example: (1, 2, 3)
# 4. Describe how dictionaries store data.
# Answer: Dictionaries store data as key-value pairs. Example: {"name": "Alice", "age": 25}.
#
# 5. Why might you use a set instead of a list in Python?
# Answer: Sets remove duplicate values automatically and allow fast lookups.
#
# 6. What is a string in Python, and how is it different from a list?
# Answer: A string is an immutable sequence of characters ("hello"), while a list is mutable and can contain multiple data types (['h', 'e', 'l', 'l', 'o']).
#
# 7. How do tuples ensure data integrity in Python?
# Answer: Tuples are immutable, preventing accidental modification of data.
#
# 8. What is a hash table, and how does it relate to dictionaries in Python?
# Answer: A hash table stores key-value pairs using a hashing function. Python dictionaries use hash tables for fast lookups.
#
# 9. Can lists contain different data types in Python?
# Answer: Yes, lists can store mixed data types, e.g., [1, "hello", 3.14, True].
#
# 10. Explain why strings are immutable in Python.
# Answer: Strings are immutable to optimize memory usage and enhance security.
#
# 11. What advantages do dictionaries offer over lists for certain tasks?
# Answer: Dictionaries allow fast key-based lookups, while lists require sequential searching.
#
# 12. Describe a scenario where using a tuple would be preferable over a list.
# Answer: Tuples are preferable for fixed data, like storing coordinates ((40.7128, -74.0060)).
#
# 13. How do sets handle duplicate values in Python?
# Answer: Sets automatically remove duplicate values. Example: {1, 2, 2, 3} → {1, 2, 3}.
#
# 14. How does the “in” keyword work differently for lists and dictionaries?
# Answer:
#
# Lists: Checks if a value exists (3 in [1, 2, 3] → True).
# Dictionaries: Checks for keys ("name" in {"name": "Alice"} → True).
# 15. Can you modify the elements of a tuple? Explain why or why not.
# Answer: No, tuples are immutable, so elements cannot be changed.
#
# 16. What is a nested dictionary, and give an example of its use case?
# Answer: A dictionary inside another dictionary. Example:
#
# python
# Copy
# Edit
# student = {"info": {"name": "Alice", "age": 20}}
# Used for structured data storage.
#
# 17. Describe the time complexity of accessing elements in a dictionary.
# Answer: Dictionary lookups have an average time complexity of O(1) due to hashing.
#
# 18. In what situations are lists preferred over dictionaries?
# Answer: Lists are preferred when order matters, and key-based lookups are unnecessary.
#
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
# Answer: Before Python 3.7, dictionaries were unordered. Now, they maintain insertion order but do not have an inherent sequence like lists.
#
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
# Answer:
#
# Lists require index-based retrieval (list[2]).
# Dictionaries allow key-based retrieval (dict["key"]).

# %%
### **1. Create a string with your name and print it**

name = "Pranjal Kishore"
print(name)

### **2. Find the length of the string "Hello World"**

string = "Hello World"
print(len(string))

### **3. Slice the first 3 characters from the string "Python Programming"**
text = "Python Programming"
print(text[:3])

### **4. Convert the string "hello" to uppercase**

text = "hello"
print(text.upper())

### **5. Replace the word "apple" with "orange" in the string "I like apple"**

sentence = "I like apple"
print(sentence.replace("apple", "orange"))

## **Lists**

### **6. Create a list with numbers 1 to 5 and print it**
numbers = [1, 2, 3, 4, 5]
print(numbers)

### **7. Append the number 10 to the list [1, 2, 3, 4]**

lst = [1, 2, 3, 4]
lst.append(10)
print(lst)

### **8. Remove the number 3 from the list [1, 2, 3, 4, 5]**
lst = [1, 2, 3, 4, 5]
lst.remove(3)
print(lst)

### **9. Access the second element in the list ['a', 'b', 'c', 'd']**
lst = ['a', 'b', 'c', 'd']
print(lst[1])

### **10. Reverse the list [10, 20, 30, 40, 50]**
lst = [10, 20, 30, 40, 50]
lst.reverse()
print(lst)

## **Tuples**

### **11. Create a tuple with elements 100, 200, 300 and print it**

tuple_data = (100, 200, 300)
print(tuple_data)

### **12. Access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow')**
tuple_colors = ('red', 'green', 'blue', 'yellow')
print(tuple_colors[-2])


### **13. Find the minimum number in the tuple (10, 20, 5, 15)**

tuple_numbers = (10, 20, 5, 15)
print(min(tuple_numbers))

### **14. Find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit')**
tuple_animals = ('dog', 'cat', 'rabbit')
print(tuple_animals.index("cat"))


### **15. Create a tuple with three different fruits and check if "kiwi" is in it**

tuple_fruits = ("apple", "banana", "cherry")
print("kiwi" in tuple_fruits)


## **Sets**

### **16. Create a set with elements 'a', 'b', 'c' and print it**

set_data = {'a', 'b', 'c'}
print(set_data)


### **17. Clear all elements from the set {1, 2, 3, 4, 5}**

set_data = {1, 2, 3, 4, 5}
set_data.clear()
print(set_data)


### **18. Remove the element 4 from the set {1, 2, 3, 4}**

set_data = {1, 2, 3, 4}
set_data.remove(4)
print(set_data)


### **19. Find the union of two sets {1, 2, 3} and {3, 4, 5}**

set1 = {1, 2, 3}
set2 = {3, 4, 5}
print(set1.union(set2))

### **20. Find the intersection of two sets {1, 2, 3} and {2, 3, 4}**
set1 = {1, 2, 3}
set2 = {2, 3, 4}
print(set1.intersection(set2))


## **Dictionaries**

##** Create a dictionary with keys "name", "age", "city" and print it**
dictionary = {"name": "Alice", "age": 25, "city": "New York"}
print(dictionary)

### **22. Add a new key-value pair "country": "USA" to the dictionary**
dictionary["country"] = "USA"
print(dictionary)

### **23. Access the value associated with the key "name" in the dictionary**

print(dictionary["name"])

### **24. Remove the key "age" from the dictionary**
del dictionary["age"]
print(dictionary)

### **25. Check if the key "city" exists in the dictionary**
print("city" in dictionary)

### **26. Create a list, a tuple, and a dictionary, and print them all**
lst = [1, 2, 3]
tuple_data = ("a", "b", "c")
dictionary = {"key1": "value1", "key2": "value2"}
print(lst, tuple_data, dictionary)

### **27. Create a list of 5 random numbers between 1 and 100, sort it, and print the result**
import random
random_numbers = random.sample(range(1, 101), 5)
random_numbers.sort()
print(random_numbers)

### **28. Create a list with strings and print the element at the third index**
str_list = ["apple", "banana", "cherry", "date", "fig"]
print(str_list[3])

### **29. Combine two dictionaries into one and print the result**
dict1 = {"a": 1, "b": 2}
dict2 = {"c": 3, "d": 4}
combined_dict = {**dict1, **dict2}
print(combined_dict)

### **30. Convert a list of strings into a set**

str_list = ["apple", "banana", "apple", "cherry"]
print(set(str_list))
# Out:
# Pranjal Kishore
# 11
# Pyt
# HELLO
# I like orange
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 10]
# [1, 2, 4, 5]
# b
# [50, 40, 30, 20, 10]
# (100, 200, 300)
# blue
# 5
# 1
# False
# {'a', 'b', 'c'}
# set()
# {1, 2, 3}
# {1, 2, 3, 4, 5}
# {2, 3}
# {'name': 'Alice', 'age': 25, 'city': 'New York'}
# {'name': 'Alice', 'age': 25, 'city': 'New York', 'country': 'USA'}
# Alice
# {'name': 'Alice', 'city': 'New York', 'country': 'USA'}
# True
# [1, 2, 3] ('a', 'b', 'c') {'key1': 'value1', 'key2': 'value2'}
# [10, 23, 26, 31, 96]
# date
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# {'apple', 'cherry', 'banana'}
